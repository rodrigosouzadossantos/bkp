# %%
#%load_ext autoreload
# %reload_ext autoreload
# %autoreload 3

# %%
import sys
sys.path.append('.')
from pathlib import Path

import tubastraea_images as t

# %%
from importlib import reload
import tubastraea_images as t
reload( t )

# %%
t.analyze_images( Path( '../..' ).resolve( ) / 'data/raw/tubastraea/images/' )

# %%
t.draw_polygons_for_dataset( Path( '../..' ).resolve( ) / 'data/raw/tubastraea/' )
