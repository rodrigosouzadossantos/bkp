# %%
sub_es.dashboard( df )
# Out:
# Tab(children=(VBox(children=(HBox(children=(VBox(children=(HTML(value='\n        <div style="\n        padding…

# %%
# !date

# %%
#%load_ext autoreload
# %reload_ext autoreload
# %autoreload 3

# %%
import sys
sys.path.append('../src')

try :
  from importlib import reload
  import subsea.easy_search as sub_es
  reload(sub_es)
except NameError :
  import subsea.easy_search as sub_es

# %%
from importlib import reload
import subsea.dashboard as dashboard
reload(dashboard)

# %%
df = sub_es.load( )

# %%
df.sample()

# %%
df.select('class_norm').n_unique( )
