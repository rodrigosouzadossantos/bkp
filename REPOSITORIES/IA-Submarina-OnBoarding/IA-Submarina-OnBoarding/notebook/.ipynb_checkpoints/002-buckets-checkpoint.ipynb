# %%
#%load_ext autoreload
# %reload_ext autoreload
# %autoreload 3

# %%
import sys
sys.path.append('../src')

try :
  from importlib import reload
  #reload(subsea.easy_search)
  #reload(subsea)
  reload(sub_es)
except NameError :
  #import subsea
  import subsea.easy_search as sub_es
# Out:
# polars.config.Config

# %%
df = sub_es.load( )

# %%
df.sample()
# Out:
# shape: (1, 58)
# ┌───────┬────────────┬───────┬────────────┬───┬──────────────┬─────────────┬─────────────┬─────────┐
# │ id    ┆ os         ┆ group ┆ group_norm ┆ … ┆ base         ┆ folder      ┆ path        ┆ source  │
# │ ---   ┆ ---        ┆ ---   ┆ ---        ┆   ┆ ---          ┆ ---         ┆ ---         ┆ ---     │
# │ i32   ┆ str        ┆ cat   ┆ cat        ┆   ┆ str          ┆ str         ┆ str         ┆ str     │
# ╞═══════╪════════════╪═══════╪════════════╪═══╪══════════════╪═════════════╪═════════════╪═════════╡
# │ 76850 ┆ 6000696840 ┆ GDS   ┆ gds        ┆ … ┆ recursos-emb ┆ SOLpa23-177 ┆ geodesia-oc ┆ Pacotes │
# │       ┆            ┆       ┆            ┆   ┆ arcacoes     ┆ _6000696840 ┆ eanografia/ ┆         │
# │       ┆            ┆       ┆            ┆   ┆              ┆             ┆ recursos…   ┆         │
# └───────┴────────────┴───────┴────────────┴───┴──────────────┴─────────────┴─────────────┴─────────┘

# %%
import polars as pl
pl.Config.set_tbl_rows( 50 )

# %%
import plotly.express as px

def bucket_similarity_matrix(df):
  df_sets = (
        df.select(["bucket", "os"]).unique()
          .group_by("bucket")
          .agg(pl.col("os").unique().alias("os_list"))
    )
  pairs = (
        df_sets.join(df_sets, how="cross", suffix="_2")
        .with_columns([
            pl.col("os_list").list.set_intersection("os_list_2").list.len().alias("inter_len"),
            pl.col("os_list").list.set_union("os_list_2").list.len().alias("union_len"),
        ])
        .with_columns((pl.col("inter_len") / pl.col("union_len")).alias("similarity"))
    )
  matrix = (
        pairs.select(["bucket", "bucket_2", "similarity"])
             .to_pandas()
             .pivot(index="bucket", columns="bucket_2", values="similarity")
             .fillna(0)
    )
  fig = px.imshow(
        matrix,
        text_auto=".2f",
        color_continuous_scale="Blues",
        aspect="auto"
    )
  fig.update_layout(
        title="Bucket Similarity Matrix",
        height=900, width=1100
    )
  fig.show()
  return matrix

# %%
bucket_similarity_matrix(df)
# Out:
# bucket_2                             instalacoes-equipamentos-submarinos  \
# bucket
# instalacoes-equipamentos-submarinos                             1.000000
# interligacao-submarina                                          0.000379
# sistemas-ancoragem                                              0.000161
# servicos-arvore-de-natal-molhada                                0.000772
# iesub-rsv                                                       0.001237
# manutencao-inspecao-submarina                                   0.000293
# geodesia-oceanografia                                           0.000998
#
# bucket_2                             interligacao-submarina  \
# bucket
# instalacoes-equipamentos-submarinos                0.000379
# interligacao-submarina                             1.000000
# sistemas-ancoragem                                 0.007149
# servicos-arvore-de-natal-molhada                   0.002508
# iesub-rsv                                          0.015130
# ...

# %%
df_sets = (
  df.select( [ 'bucket', 'os' ] )
    .group_by( 'bucket' )
    .agg( pl.col( 'os' ).alias( 'os_list' ) )
)

pairs = (
  df_sets.join(
    df_sets, how = 'cross', suffix = '_2'
  ).filter(
    pl.col( 'bucket' ) != pl.col( 'bucket_2' )
  )
)
# Out:
# shape: (7, 2)
# ┌─────────────────────────────────┬─────────────────────────────────┐
# │ bucket                          ┆ os_list                         │
# │ ---                             ┆ ---                             │
# │ cat                             ┆ list[str]                       │
# ╞═════════════════════════════════╪═════════════════════════════════╡
# │ interligacao-submarina          ┆ ["6000783348", "6000739414", …… │
# │ sistemas-ancoragem              ┆ ["6000792398", "6000792398", …… │
# │ instalacoes-equipamentos-subma… ┆ ["6000740104", "6000752688", …… │
# │ servicos-arvore-de-natal-molha… ┆ ["6000797937", "6000797560", …… │
# │ iesub-rsv                       ┆ ["6000780910", "6000780909", …… │
# │ manutencao-inspecao-submarina   ┆ ["6000789371", "6000749623", …… │
# │ geodesia-oceanografia           ┆ ["6000795361", "6000686190", …… │
# └─────────────────────────────────┴─────────────────────────────────┘

# %%
df_sets.join( df_sets, how = 'cross', suffix = '_2' ).filter( pl.col( 'bucket' ) != pl.col( 'bucket_2' ) )
# Out:
# shape: (42, 4)
# ┌──────────────────────────────┬──────────────────┬─────────────────────────────┬──────────────────┐
# │ bucket                       ┆ os_list          ┆ bucket_2                    ┆ os_list_2        │
# │ ---                          ┆ ---              ┆ ---                         ┆ ---              │
# │ cat                          ┆ list[str]        ┆ cat                         ┆ list[str]        │
# ╞══════════════════════════════╪══════════════════╪═════════════════════════════╪══════════════════╡
# │ sistemas-ancoragem           ┆ ["6000792398",   ┆ interligacao-submarina      ┆ ["6000783348",   │
# │                              ┆ "6000795236", …… ┆                             ┆ "6000739414", …… │
# │ sistemas-ancoragem           ┆ ["6000792398",   ┆ instalacoes-equipamentos-su ┆ ["6000740104",   │
# │                              ┆ "6000795236", …… ┆ bma…                        ┆ "6000752688", …… │
# ...

# %%
pl.col("os_list").list.set_intersection("os_list_2").alias("intersection")
# Out:
# <Expr ['col("os_list").list.intersecti…'] at 0x1540631EF350>

# %%
pairs = pairs.with_columns([
    pl.col("os_list").list.set_intersection("os_list_2").alias("intersection"),
    pl.col("os_list").list.set_union("os_list_2").alias("union"),
    (
        pl.col("os_list").list.set_intersection("os_list_2").list.len()
        /
        pl.col("os_list").list.set_union("os_list_2").list.len()
    ).alias("similarity")
])

# %%
pairs
# Out:
# shape: (42, 7)
# ┌──────────────┬──────────────┬─────────────┬─────────────┬─────────────┬─────────────┬────────────┐
# │ bucket       ┆ os_list      ┆ bucket_2    ┆ os_list_2   ┆ intersectio ┆ union       ┆ similarity │
# │ ---          ┆ ---          ┆ ---         ┆ ---         ┆ n           ┆ ---         ┆ ---        │
# │ cat          ┆ list[str]    ┆ cat         ┆ list[str]   ┆ ---         ┆ list[str]   ┆ f64        │
# │              ┆              ┆             ┆             ┆ list[str]   ┆             ┆            │
# ╞══════════════╪══════════════╪═════════════╪═════════════╪═════════════╪═════════════╪════════════╡
# │ sistemas-anc ┆ ["6000792398 ┆ interligaca ┆ ["600078334 ┆ ["600078228 ┆ ["600079239 ┆ 0.007149   │
# │ oragem       ┆ ", "60007952 ┆ o-submarina ┆ 8", "600073 ┆ 4", "600078 ┆ 8", "600079 ┆            │
# │              ┆ 36", ……      ┆             ┆ 9414", ……   ┆ 7642", ……   ┆ 5236", ……   ┆            │
# ...

# %%
( df_sets.join(df_sets, how="cross", suffix="_2")
.with_columns([
    pl.col("os_list").list.set_intersection("os_list_2").list.len().alias("inter_len"),
    pl.col("os_list").list.set_union("os_list_2").list.len().alias("union_len"),
])
.with_columns((pl.col("inter_len") / pl.col("union_len")).alias("similarity")) )
# Out:
# shape: (49, 7)
# ┌───────────────┬───────────────┬──────────────┬──────────────┬───────────┬───────────┬────────────┐
# │ bucket        ┆ os_list       ┆ bucket_2     ┆ os_list_2    ┆ inter_len ┆ union_len ┆ similarity │
# │ ---           ┆ ---           ┆ ---          ┆ ---          ┆ ---       ┆ ---       ┆ ---        │
# │ cat           ┆ list[str]     ┆ cat          ┆ list[str]    ┆ u32       ┆ u32       ┆ f64        │
# ╞═══════════════╪═══════════════╪══════════════╪══════════════╪═══════════╪═══════════╪════════════╡
# │ sistemas-anco ┆ ["6000792398" ┆ sistemas-anc ┆ ["6000792398 ┆ 5460      ┆ 5460      ┆ 1.0        │
# │ ragem         ┆ ,             ┆ oragem       ┆ ", "60007952 ┆           ┆           ┆            │
# │               ┆ "6000795236", ┆              ┆ 36", ……      ┆           ┆           ┆            │
# │               ┆ ……            ┆              ┆              ┆           ┆           ┆            │
# ...
