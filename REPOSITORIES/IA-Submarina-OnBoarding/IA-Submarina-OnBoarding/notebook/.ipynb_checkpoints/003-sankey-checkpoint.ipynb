# %%
#%load_ext autoreload
# %reload_ext autoreload
# %autoreload 3

# %%
import sys
sys.path.append('../src')

try :
  from importlib import reload
  #reload(subsea.easy_search)
  #reload(subsea)
  reload(sub_es)
except NameError :
  #import subsea
  import subsea.easy_search as sub_es

# %%
df = sub_es.load( )

# %%
df.sample()
# Out:
# shape: (1, 58)
# ┌───────┬────────────┬───────┬────────────┬───┬──────────────┬─────────────┬─────────────┬─────────┐
# │ id    ┆ os         ┆ group ┆ group_norm ┆ … ┆ base         ┆ folder      ┆ path        ┆ source  │
# │ ---   ┆ ---        ┆ ---   ┆ ---        ┆   ┆ ---          ┆ ---         ┆ ---         ┆ ---     │
# │ i32   ┆ str        ┆ cat   ┆ cat        ┆   ┆ str          ┆ str         ┆ str         ┆ str     │
# ╞═══════╪════════════╪═══════╪════════════╪═══╪══════════════╪═════════════╪═════════════╪═════════╡
# │ 73116 ┆ 6000664129 ┆ CRD   ┆ crd        ┆ … ┆ recursos-emb ┆ OS006000664 ┆ manutencao- ┆ Pacotes │
# │       ┆            ┆       ┆            ┆   ┆ arcacoes     ┆ 129-NPBAZ23 ┆ inspecao-su ┆         │
# │       ┆            ┆       ┆            ┆   ┆              ┆ -116        ┆ bmarina/…   ┆         │
# └───────┴────────────┴───────┴────────────┴───┴──────────────┴─────────────┴─────────────┴─────────┘

# %%
df.shape
# Out:
# (74702, 58)

# %%
import polars as pl

# %%
df_sets = (
    df
      .select(["bucket", "os"])
      .group_by("bucket")
      .agg(pl.col("os").unique().alias("os_list"))
)

pairs = (
    df_sets.join(df_sets, how="cross", suffix="_2")
            .filter(pl.col("bucket") != pl.col("bucket_2"))
)

pairs = pairs.with_columns([
    pl.col("os_list").list.set_intersection("os_list_2").alias("intersection"),
    pl.col("os_list").list.set_union("os_list_2").alias("union"),
    (
        pl.col("os_list").list.set_intersection("os_list_2").list.len()
        /
        pl.col("os_list").list.set_union("os_list_2").list.len()
    ).alias("similarity")
])

# %%
pairs.sort("similarity", descending=True)
# Out:
# shape: (42, 7)
# ┌──────────────┬──────────────┬─────────────┬─────────────┬─────────────┬─────────────┬────────────┐
# │ bucket       ┆ os_list      ┆ bucket_2    ┆ os_list_2   ┆ intersectio ┆ union       ┆ similarity │
# │ ---          ┆ ---          ┆ ---         ┆ ---         ┆ n           ┆ ---         ┆ ---        │
# │ cat          ┆ list[str]    ┆ cat         ┆ list[str]   ┆ ---         ┆ list[str]   ┆ f64        │
# │              ┆              ┆             ┆             ┆ list[str]   ┆             ┆            │
# ╞══════════════╪══════════════╪═════════════╪═════════════╪═════════════╪═════════════╪════════════╡
# │ interligacao ┆ ["6000783348 ┆ manutencao- ┆ ["600078937 ┆ ["600072228 ┆ ["600078334 ┆ 0.020857   │
# │ -submarina   ┆ ", "60007394 ┆ inspecao-su ┆ 1", "600074 ┆ 5", "600077 ┆ 8", "600073 ┆            │
# │              ┆ 14", ……      ┆ bmarina     ┆ 9623", ……   ┆ 8893", ……   ┆ 9414", ……   ┆            │
# │ manutencao-i ┆ ["6000789371 ┆ interligaca ┆ ["600078334 ┆ ["600075967 ┆ ["600078937 ┆ 0.020857   │
# │ nspecao-subm ┆ ", "60007496 ┆ o-submarina ┆ 8", "600073 ┆ 8", "600078 ┆ 1", "600074 ┆            │
# │ arina        ┆ 23", ……      ┆             ┆ 9414", ……   ┆ 5215", ……   ┆ 9623", ……   ┆            │
# │ interligacao ┆ ["6000783348 ┆ iesub-rsv   ┆ ["600078091 ┆ ["600072228 ┆ ["600078334 ┆ 0.01513    │
# │ -submarina   ┆ ", "60007394 ┆             ┆ 0", "600078 ┆ 5", "600077 ┆ 8", "600073 ┆            │
# │              ┆ 14", ……      ┆             ┆ 0909", ……   ┆ 6699", ……   ┆ 9414", ……   ┆            │
# │ iesub-rsv    ┆ ["6000780910 ┆ interligaca ┆ ["600078334 ┆ ["600077669 ┆ ["600078091 ┆ 0.01513    │
# │              ┆ ", "60007809 ┆ o-submarina ┆ 8", "600073 ┆ 9", "600077 ┆ 0", "600078 ┆            │
# │              ┆ 09", ……      ┆             ┆ 9414", ……   ┆ 9038", ……   ┆ 0909", ……   ┆            │
# │ servicos-arv ┆ ["6000797937 ┆ iesub-rsv   ┆ ["600078091 ┆ ["600074642 ┆ ["600079793 ┆ 0.010776   │
# │ ore-de-natal ┆ ", "60007975 ┆             ┆ 0", "600078 ┆ 3", "600078 ┆ 7", "600079 ┆            │
# │ -molha…      ┆ 60", ……      ┆             ┆ 0909", ……   ┆ 9697", ……   ┆ 7560", ……   ┆            │
# │ …            ┆ …            ┆ …           ┆ …           ┆ …           ┆ …           ┆ …          │
# │ instalacoes- ┆ ["6000740104 ┆ interligaca ┆ ["600078334 ┆ ["600075982 ┆ ["600074010 ┆ 0.000379   │
# │ equipamentos ┆ ", "60007526 ┆ o-submarina ┆ 8", "600073 ┆ 9", "600071 ┆ 4", "600075 ┆            │
# │ -subma…      ┆ 88", ……      ┆             ┆ 9414", ……   ┆ 3603"]      ┆ 2688", ……   ┆            │
# │ instalacoes- ┆ ["6000740104 ┆ manutencao- ┆ ["600078937 ┆ ["600073001 ┆ ["600074010 ┆ 0.000293   │
# │ equipamentos ┆ ", "60007526 ┆ inspecao-su ┆ 1", "600074 ┆ 8", "600072 ┆ 4", "600075 ┆            │
# │ -subma…      ┆ 88", ……      ┆ bmarina     ┆ 9623", ……   ┆ 6922", ……   ┆ 2688", ……   ┆            │
# │ manutencao-i ┆ ["6000789371 ┆ instalacoes ┆ ["600074010 ┆ [null, "600 ┆ ["600078937 ┆ 0.000293   │
# │ nspecao-subm ┆ ", "60007496 ┆ -equipament ┆ 4", "600075 ┆ 0730018", … ┆ 1", "600074 ┆            │
# │ arina        ┆ 23", ……      ┆ os-subma…   ┆ 2688", ……   ┆ "600061…    ┆ 9623", ……   ┆            │
# │ sistemas-anc ┆ ["6000792398 ┆ instalacoes ┆ ["600074010 ┆ [null]      ┆ ["600079239 ┆ 0.000161   │
# │ oragem       ┆ ", "60007952 ┆ -equipament ┆ 4", "600075 ┆             ┆ 8", "600079 ┆            │
# │              ┆ 36", ……      ┆ os-subma…   ┆ 2688", ……   ┆             ┆ 5236", ……   ┆            │
# │ instalacoes- ┆ ["6000740104 ┆ sistemas-an ┆ ["600079239 ┆ [null]      ┆ ["600074010 ┆ 0.000161   │
# │ equipamentos ┆ ", "60007526 ┆ coragem     ┆ 8", "600079 ┆             ┆ 4", "600075 ┆            │
# │ -subma…      ┆ 88", ……      ┆             ┆ 5236", ……   ┆             ┆ 2688", ……   ┆            │
# └──────────────┴──────────────┴─────────────┴─────────────┴─────────────┴─────────────┴────────────┘

# %%
pairs.filter(pl.col("similarity") > 0.80)
# Out:
# shape: (0, 7)
# ┌────────┬───────────┬──────────┬───────────┬──────────────┬───────────┬────────────┐
# │ bucket ┆ os_list   ┆ bucket_2 ┆ os_list_2 ┆ intersection ┆ union     ┆ similarity │
# │ ---    ┆ ---       ┆ ---      ┆ ---       ┆ ---          ┆ ---       ┆ ---        │
# │ cat    ┆ list[str] ┆ cat      ┆ list[str] ┆ list[str]    ┆ list[str] ┆ f64        │
# ╞════════╪═══════════╪══════════╪═══════════╪══════════════╪═══════════╪════════════╡
# └────────┴───────────┴──────────┴───────────┴──────────────┴───────────┴────────────┘

# %%
import plotly.express as px
def bucket_similarity_matrix(df):
  df_sets = (
        df.select(["bucket", "os"]).unique()
          .group_by("bucket")
          .agg(pl.col("os").unique().alias("os_list"))
    )
  pairs = (
        df_sets.join(df_sets, how="cross", suffix="_2")
        .with_columns([
            pl.col("os_list").list.set_intersection("os_list_2").list.len().alias("inter_len"),
            pl.col("os_list").list.set_union("os_list_2").list.len().alias("union_len"),
        ])
        .with_columns((pl.col("inter_len") / pl.col("union_len")).alias("similarity"))
    )
  matrix = (
        pairs.select(["bucket", "bucket_2", "similarity"])
             .to_pandas()
             .pivot(index="bucket", columns="bucket_2", values="similarity")
             .fillna(0)
    )
  fig = px.imshow(
        matrix,
        text_auto=".2f",
        color_continuous_scale="Blues",
        aspect="auto"
    )
  fig.update_layout(
        title="Bucket Similarity Matrix",
        height=900, width=1100
    )
  fig.show()
  return matrix

# %%
bucket_similarity_matrix(df)
# Out:
# bucket_2                             sistemas-ancoragem  \
# bucket
# sistemas-ancoragem                             1.000000
# instalacoes-equipamentos-submarinos            0.000161
# interligacao-submarina                         0.007149
# servicos-arvore-de-natal-molhada               0.001507
# iesub-rsv                                      0.005621
# geodesia-oceanografia                          0.001815
# manutencao-inspecao-submarina                  0.005990
#
# bucket_2                             instalacoes-equipamentos-submarinos  \
# bucket
# sistemas-ancoragem                                              0.000161
# instalacoes-equipamentos-submarinos                             1.000000
# interligacao-submarina                                          0.000379
# servicos-arvore-de-natal-molhada                                0.000772
# iesub-rsv                                                       0.001237
# geodesia-oceanografia                                           0.000998
# manutencao-inspecao-submarina                                   0.000293
#
# bucket_2                             interligacao-submarina  \
# bucket
# sistemas-ancoragem                                 0.007149
# instalacoes-equipamentos-submarinos                0.000379
# interligacao-submarina                             1.000000
# servicos-arvore-de-natal-molhada                   0.002508
# iesub-rsv                                          0.015130
# geodesia-oceanografia                              0.003831
# manutencao-inspecao-submarina                      0.020857
#
# bucket_2                             servicos-arvore-de-natal-molhada  \
# bucket
# sistemas-ancoragem                                           0.001507
# instalacoes-equipamentos-submarinos                          0.000772
# interligacao-submarina                                       0.002508
# servicos-arvore-de-natal-molhada                             1.000000
# iesub-rsv                                                    0.010776
# geodesia-oceanografia                                        0.000972
# manutencao-inspecao-submarina                                0.001345
#
# bucket_2                             iesub-rsv  geodesia-oceanografia  \
# bucket
# sistemas-ancoragem                    0.005621               0.001815
# instalacoes-equipamentos-submarinos   0.001237               0.000998
# interligacao-submarina                0.015130               0.003831
# servicos-arvore-de-natal-molhada      0.010776               0.000972
# iesub-rsv                             1.000000               0.001617
# geodesia-oceanografia                 0.001617               1.000000
# manutencao-inspecao-submarina         0.005456               0.001920
#
# bucket_2                             manutencao-inspecao-submarina
# bucket
# sistemas-ancoragem                                        0.005990
# instalacoes-equipamentos-submarinos                       0.000293
# interligacao-submarina                                    0.020857
# servicos-arvore-de-natal-molhada                          0.001345
# iesub-rsv                                                 0.005456
# geodesia-oceanografia                                     0.001920
# manutencao-inspecao-submarina                             1.000000

# %%
# Out:
# shape: (74_702, 2)
# ┌─────────────────────────────────┬────────────┐
# │ bucket                          ┆ os         │
# │ ---                             ┆ ---        │
# │ cat                             ┆ str        │
# ╞═════════════════════════════════╪════════════╡
# │ sistemas-ancoragem              ┆ 6000792398 │
# │ servicos-arvore-de-natal-molha… ┆ 6000797937 │
# │ servicos-arvore-de-natal-molha… ┆ 6000797560 │
# │ manutencao-inspecao-submarina   ┆ 6000789371 │
# │ manutencao-inspecao-submarina   ┆ 6000749623 │
# │ …                               ┆ …          │
# │ manutencao-inspecao-submarina   ┆ 6000555846 │
# │ manutencao-inspecao-submarina   ┆ 6000542122 │
# │ manutencao-inspecao-submarina   ┆ 6000559301 │
# │ manutencao-inspecao-submarina   ┆ 6000559301 │
# │ manutencao-inspecao-submarina   ┆ 6000559301 │
# └─────────────────────────────────┴────────────┘

# %%
df.select( [ 'bucket', 'os' ] ).group_by( 'bucket' )
