# %%
# !python -V
# Out:
# Python 3.12.3

# %%
import polars as pl
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import polars as pl
#
# ModuleNotFoundError: No module named 'polars'

# %%
# !PIP_REQUIRE_VIRTUALENV=false pip install xlsx2csv
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: http://nexus.petrobras.com.br/nexus/repository/pypi-all/simple
# ...

# %%
pip install xlsx2csv
# Out:
# ERROR: Could not find an activated virtualenv (required).
# Note: you may need to restart the kernel to use updated packages.

# %%
# !printenv
# Out:
# SHELL=/bin/bash
# SLURM_STEP_NUM_TASKS=12
# JUPYTERHUB_ADMIN_ACCESS=1
# SLURM_JOB_USER=ghva
# SLURM_TASKS_PER_NODE=12
# SLURM_JOB_UID=5202782
# HISTCONTROL=ignoreboth
# SLURM_EXPORT_ENV=LANG,JUPYTERHUB_API_TOKEN,JPY_API_TOKEN,JUPYTERHUB_ADMIN_ACCESS,JUPYTERHUB_CLIENT_ID,JUPYTERHUB_HOST,JUPYTERHUB_OAUTH_CALLBACK_URL,JUPYTERHUB_USER,JUPYTERHUB_API_URL,JUPYTERHUB_BASE_URL,JUPYTERHUB_SERVICE_PREFIX,USER,HOME,SHELL
# SLURM_TASK_PID=2911759
# SLURM_LOCALID=9
# SLURM_SUBMIT_DIR=/projetos/ghva
# HOSTNAME=cds1cpun04
# HISTSIZE=5000
# SINGULARITY_NAME=cdi_cpu_gpu.sif
# SLURMD_NODENAME=cds1cpun04
# FPATH=/usr/share/lmod/lmod/init/ksh_funcs
# JUPYTERHUB_API_TOKEN=6cc9b6d308c44d9c8184cef75e518773
# SLURM_STEP_NODELIST=cds1cpun04
# JUPYTERLAB_WORKSPACES_DIR=/projetos/ghva/.jupyter/lab/workspaces/
# JUPYTERHUB_BASE_URL=/
# HISTTIMEFORMAT=%F %T
# TF_CPP_MIN_LOG_LEVEL=2
# SLURM_NODE_ALIASES=(null)
# SLURM_CLUSTER_NAME=cds1
# DISTTAG=f39container
# SLURM_CPUS_ON_NODE=12
# MEM_LIMIT=66571993088
# ...
