# %%
import polars as pl

# %%
# !pip install xlsx2csv
# Out:
# ERROR: Could not find an activated virtualenv (required).

# %%
import polars as pl
df = pl.read_excel("Pacotes.xlsx")
print(df)
# Out:
# shape: (47_777, 34)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ Atualizad ┆ _duplicat ┆ _duplicat ┆ _duplicat ┆ … ┆ _duplicat ┆ _duplicat ┆ _duplicat ┆ _duplica │
# │ o em 2026 ┆ ed_0      ┆ ed_1      ┆ ed_2      ┆   ┆ ed_29     ┆ ed_30     ┆ ed_31     ┆ ted_32   │
# │ -01-14    ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │ ---       ┆ str       ┆ str       ┆ str       ┆   ┆ str       ┆ str       ┆ str       ┆ str      │
# │ str       ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ Dados     ┆ null      ┆ null      ┆ Referênci ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ Básicos   ┆           ┆           ┆ as        ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ Externas  ┆   ┆           ┆           ┆           ┆          │
# │ Id        ┆ Nome da   ┆ Caminho   ┆ Ordem de  ┆ … ┆ Local     ┆ Objetivo  ┆ Objetivo  ┆ Lâmina   │
# │           ┆ Pasta     ┆ Completo  ┆ Serviço   ┆   ┆ (Origem)  ┆ (Demanda) ┆ (Entrega) ┆ d'água   │
# │ 112432    ┆ OS0060007 ┆ sistemas- ┆ 600079239 ┆ … ┆ 7-CG-5HP- ┆ 7-CG-5HP- ┆ Abandonos ┆ 283      │
# │           ┆ 92398     ┆ ancoragem ┆ 8         ┆   ┆ RJS       ┆ RJS       ┆ 2022      ┆          │
# │           ┆           ┆ /recursos ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ -em…      ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 112431    ┆ OS0060007 ┆ servicos- ┆ 600079793 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │           ┆ 97937     ┆ arvore-de ┆ 7         ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ -natal-mo ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ lha…      ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 112430    ┆ OS0060007 ┆ servicos- ┆ 600079756 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │           ┆ 97560     ┆ arvore-de ┆ 0         ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ -natal-mo ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ lha…      ┆           ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ 4178      ┆ OS0060004 ┆ manutenca ┆ 600048702 ┆ … ┆ 1-RJS-414 ┆ ou BC /   ┆ Inspecoes ┆ 129      │
# │           ┆ 87025-JGC ┆ o-inspeca ┆ 5         ┆   ┆           ┆ ATP - N   ┆ (ICPI)    ┆          │
# │           ┆ O21-014   ┆ o-submari ┆           ┆   ┆           ┆           ┆ UO-BC     ┆          │
# │           ┆           ┆ na/…      ┆           ┆   ┆           ┆           ┆ 2018      ┆          │
# │ 4177      ┆ OS0060004 ┆ manutenca ┆ 600048666 ┆ … ┆ 7-CRT-17H ┆ ATP-BRC   ┆ Inspecoes ┆ 1080     │
# │           ┆ 86667-JGC ┆ o-inspeca ┆ 7         ┆   ┆ P-RJS     ┆           ┆ (ICPI)    ┆          │
# │           ┆ RT21-020  ┆ o-submari ┆           ┆   ┆           ┆           ┆ UO-RIO    ┆          │
# │           ┆           ┆ na/…      ┆           ┆   ┆           ┆           ┆ 2018      ┆          │
# │ 4107      ┆ OS0060005 ┆ manutenca ┆ 600055814 ┆ … ┆ 7-MRL-156 ┆ ATP-MRL   ┆ Inspecoes ┆ 962      │
# │           ┆ 58142-JGM ┆ o-inspeca ┆ 2         ┆   ┆ HP-RJS    ┆           ┆ (ICPI)    ┆          │
# │           ┆ RL21-027  ┆ o-submari ┆           ┆   ┆           ┆           ┆ UO-BC     ┆          │
# │           ┆           ┆ na/…      ┆           ┆   ┆           ┆           ┆ 2020      ┆          │
# │ 3292      ┆ OS0060005 ┆ manutenca ┆ 600053004 ┆ … ┆ 8-BUZ-22D ┆ 8-BUZ-22D ┆ 8-BUZ-22D ┆ 1988     │
# │           ┆ 30044-SAC ┆ o-inspeca ┆ 4         ┆   ┆ -RJS      ┆ -RJS      ┆ -RJS      ┆          │
# │           ┆ BUZ20-139 ┆ o-submari ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ na/…      ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 1904      ┆ 2020-10-1 ┆ manutenca ┆ 600055347 ┆ … ┆ P-26      ┆ Inspecoes ┆ Inspecoes ┆ 990      │
# │           ┆ 3-OS00600 ┆ o-inspeca ┆ 6         ┆   ┆           ┆ de dutos  ┆ (ICPI)    ┆          │
# │           ┆ 0553476-P ┆ o-submari ┆           ┆   ┆           ┆ - ATP -   ┆ UO-BC     ┆          │
# │           ┆ IDF…      ┆ na/…      ┆           ┆   ┆           ┆ MRL       ┆ 2020      ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
# !echo "id os group desc date class un field_number field_location depth suit shipment company resource vessel relatbar n1710 files_count files_size files_missing_count files_missing_size files_oldest files_newest inventory_first inventory_newest files_missing_lastseen bucket base folder path" | tr ' ' '\n' \
| sed -r 's/^(.*)$/  "\1" : pl.Utf8,/'
# Out:
#   "id" : pl.Utf8,
#   "os" : pl.Utf8,
#   "group" : pl.Utf8,
#   "desc" : pl.Utf8,
#   "date" : pl.Utf8,
#   "class" : pl.Utf8,
#   "un" : pl.Utf8,
#   "field_number" : pl.Utf8,
#   "field_location" : pl.Utf8,
#   "depth" : pl.Utf8,
#   "suit" : pl.Utf8,
#   "shipment" : pl.Utf8,
#   "company" : pl.Utf8,
#   "resource" : pl.Utf8,
#   "vessel" : pl.Utf8,
#   "relatbar" : pl.Utf8,
#   "n1710" : pl.Utf8,
#   "files_count" : pl.Utf8,
#   "files_size" : pl.Utf8,
#   "files_missing_count" : pl.Utf8,
#   "files_missing_size" : pl.Utf8,
#   "files_oldest" : pl.Utf8,
#   "files_newest" : pl.Utf8,
#   "inventory_first" : pl.Utf8,
#   "inventory_newest" : pl.Utf8,
#   "files_missing_lastseen" : pl.Utf8,
#   "bucket" : pl.Utf8,
#   "base" : pl.Utf8,
#   "folder" : pl.Utf8,
#   "path" : pl.Utf8,

# %%
import polars as pl

# ============================================
# Define schema based on your description
# ============================================

schema = {
  "id"     : pl.Int32,

  "os"     : pl.Categorical,
  "group"  : pl.Categorical,
  "desc"   : pl.Utf8,
  "date"   : pl.Date,
  "class"  : pl.Utf8,
  "un"     : pl.Categorical,

  "field_number"   : pl.Int16,
  "field_location" : pl.Categorical,
  "depth"          : pl.Int32, # could not parse `87693` as dtype `i16` at column 'depth'

  "suit"     : pl.Utf8,
  "shipment" : pl.Utf8,

  "company"  : pl.Categorical,
  "resource" : pl.Categorical,
  "vessel"   : pl.Categorical,
  "relatbar" : pl.Utf8,
  "n1710"    : pl.Utf8,

  "files_count" : pl.Int64,
  "files_size"  : pl.Float64,
  "files_missing_count" : pl.Int64,
  "files_missing_size"  : pl.Float64,
  "files_oldest"     : pl.Date,
  "files_newest"     : pl.Date,
  "inventory_first"  : pl.Date,
  "inventory_newest" : pl.Date,
  "files_missing_lastseen" : pl.Date,

  "bucket" : pl.Categorical,
  "base"   : pl.Utf8,
  "folder" : pl.Utf8,
  "path"   : pl.Utf8,
}

# ============================================
# Load CSV with forced schema
# ============================================
df = pl.read_excel(
  'dados-submarinos.xlsx',
  sheet_name = None,
  schema_overrides = schema,
  infer_schema_length = None
)

# ============================================
# 
# ============================================
for col, dtype in df.schema.items():
  if dtype == pl.Categorical:
    phys_name  = f'{col}_physical'
    count_name = f'{col}_count'
    df = df.with_columns(
      pl.col( col )
        .to_physical( )
        .alias( phys_name ),
      pl.col( col )
        .count( )
        .over( col )
        .alias( count_name )
    )

    # rearrange so the physical column is placed immediately after the original
    cols = df.columns
    
    cols.remove( count_name )
    cols.insert(
      cols.index( col ) + 1, count_name
    )
    
    cols.remove( phys_name )
    cols.insert(
      cols.index( col ) + 1, phys_name
    )
    
    df = df.select( cols )


# ============================================
# 
# ============================================
df = df.with_columns(
  pl.col( 'company' )
    .fill_null(
      pl.col( 'company' )
      .forward_fill( )
      .over( 'vessel' )
    )
)

# ============================================
# Save as Parquet
# ============================================
df.write_parquet("dados-submarinos-all.parquet")

print('XLSX successfully converted to Parquet with correct data types!')

print( df.dtypes )
df.head( )
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 49
#       7 schema = {
#       8   "id"     : pl.Int32,
#       9
#    (...)
#      43   "path"   : pl.Utf8,
#      44 }
#      46 # ============================================
#      47 # Load CSV with forced schema
#      48 # ============================================
# ---> 49 df = pl.read_excel(
#      50   'dados-submarinos.xlsx',
#      51   sheet_name = None,
#      52   schema_overrides = schema,
#      53   infer_schema_length = None
#      54 )
#      56 # ============================================
#      57 #
#      58 # ============================================
#      59 for col, dtype in df.schema.items():
#
# File /usr/local/lib64/python3.12/site-packages/polars/_utils/deprecation.py:135, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     130 @wraps(function)
#     131 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#     132     _rename_keyword_argument(
#     133         old_name, new_name, kwargs, function.__name__, version
#     134     )
# --> 135     return function(*args, **kwargs)
#
# File /usr/local/lib64/python3.12/site-packages/polars/_utils/deprecation.py:135, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     130 @wraps(function)
#     131 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#     132     _rename_keyword_argument(
#     133         old_name, new_name, kwargs, function.__name__, version
#     134     )
# --> 135     return function(*args, **kwargs)
#
# File /usr/local/lib64/python3.12/site-packages/polars/io/spreadsheet/functions.py:276, in read_excel(source, sheet_id, sheet_name, engine, engine_options, read_options, schema_overrides, infer_schema_length, raise_if_empty)
#     138 @deprecate_renamed_parameter("xlsx2csv_options", "engine_options", version="0.20.6")
#     139 @deprecate_renamed_parameter("read_csv_options", "read_options", version="0.20.7")
#     140 def read_excel(
#    (...)
#     150     raise_if_empty: bool = True,
#     151 ) -> pl.DataFrame | dict[str, pl.DataFrame]:
#     152     """
#     153     Read Excel spreadsheet data into a DataFrame.
#     154
#    (...)
#     274     ... )  # doctest: +SKIP
#     275     """
# --> 276     return _read_spreadsheet(
#     277         sheet_id,
#     278         sheet_name,
#     279         source=source,
#     280         engine=engine,
#     281         engine_options=engine_options,
#     282         read_options=read_options,
#     283         schema_overrides=schema_overrides,
#     284         infer_schema_length=infer_schema_length,
#     285         raise_if_empty=raise_if_empty,
#     286     )
#
# File /usr/local/lib64/python3.12/site-packages/polars/io/spreadsheet/functions.py:524, in _read_spreadsheet(sheet_id, sheet_name, source, engine, engine_options, read_options, schema_overrides, infer_schema_length, raise_if_empty)
#     521     read_options["infer_schema_length"] = infer_schema_length
#     523 # establish the reading function, parser, and available worksheets
# --> 524 reader_fn, parser, worksheets = _initialise_spreadsheet_parser(
#     525     engine, source, engine_options
#     526 )
#     527 try:
#     528     # parse data from the indicated sheet(s)
#     529     sheet_names, return_multi = _get_sheet_names(sheet_id, sheet_name, worksheets)
#
# File /usr/local/lib64/python3.12/site-packages/polars/io/spreadsheet/functions.py:611, in _initialise_spreadsheet_parser(engine, source, engine_options)
#     608     raise FileNotFoundError(source)
#     610 if engine == "xlsx2csv":  # default
# --> 611     xlsx2csv = import_optional("xlsx2csv")
#     613     # establish sensible defaults for unset options
#     614     for option, value in {
#     615         "exclude_hidden_sheets": False,
#     616         "skip_empty_lines": False,
#     617         "skip_hidden_rows": False,
#     618         "floatformat": "%f",
#     619     }.items():
#
# File /usr/local/lib64/python3.12/site-packages/polars/dependencies.py:277, in import_optional(module_name, err_prefix, err_suffix, min_version, min_err_prefix, install_message)
#     272     suffix = f" {err_suffix.strip(' ')}" if err_suffix else ""
#     273     err_message = f"{prefix}'{module_name}'{suffix}.\n" + (
#     274         install_message
#     275         or f"Please install using the command `pip install {module_root}`."
#     276     )
# --> 277     raise ModuleNotFoundError(err_message) from None
#     279 if min_version:
#     280     min_version = parse_version(min_version)
#
# ModuleNotFoundError: required package 'xlsx2csv' not found.
# Please install using the command `pip install xlsx2csv`.

# %%
df = pl.read_parquet( 'dados-submarinos-pacotes.parquet' )
df
#df = df.with_columns(
#  pl.col( 'depth' ).cast( pl.Int32 )
#)
#df.write_parquet("dados-submarinos.parquet")
# Out:
# shape: (47_775, 38)
# ┌────────┬────────────┬────────────┬───────┬───┬────────────┬────────────┬────────────┬────────────┐
# │ id     ┆ os         ┆ os_physica ┆ group ┆ … ┆ bucket_phy ┆ base       ┆ folder     ┆ path       │
# │ ---    ┆ ---        ┆ l          ┆ ---   ┆   ┆ sical      ┆ ---        ┆ ---        ┆ ---        │
# │ i32    ┆ cat        ┆ ---        ┆ cat   ┆   ┆ ---        ┆ str        ┆ str        ┆ str        │
# │        ┆            ┆ u32        ┆       ┆   ┆ u32        ┆            ┆            ┆            │
# ╞════════╪════════════╪════════════╪═══════╪═══╪════════════╪════════════╪════════════╪════════════╡
# │ 112432 ┆ 6000792398 ┆ 0          ┆ ANC   ┆ … ┆ 4008       ┆ recursos-e ┆ OS00600079 ┆ sistemas-a │
# │        ┆            ┆            ┆       ┆   ┆            ┆ mbarcacoes ┆ 2398       ┆ ncoragem/r │
# │        ┆            ┆            ┆       ┆   ┆            ┆            ┆            ┆ ecursos-em │
# │        ┆            ┆            ┆       ┆   ┆            ┆            ┆            ┆ …          │
# │ 112431 ┆ 6000797937 ┆ 1          ┆ null  ┆ … ┆ 4009       ┆ recursos-e ┆ OS00600079 ┆ servicos-a │
# │        ┆            ┆            ┆       ┆   ┆            ┆ mbarcacoes ┆ 7937       ┆ rvore-de-n │
# │        ┆            ┆            ┆       ┆   ┆            ┆            ┆            ┆ atal-molha │
# │        ┆            ┆            ┆       ┆   ┆            ┆            ┆            ┆ …          │
# │ 112430 ┆ 6000797560 ┆ 2          ┆ null  ┆ … ┆ 4009       ┆ recursos-e ┆ OS00600079 ┆ servicos-a │
# │        ┆            ┆            ┆       ┆   ┆            ┆ mbarcacoes ┆ 7560       ┆ rvore-de-n │
# │        ┆            ┆            ┆       ┆   ┆            ┆            ┆            ┆ atal-molha │
# │        ┆            ┆            ┆       ┆   ┆            ┆            ┆            ┆ …          │
# │ 112429 ┆ 6000789371 ┆ 3          ┆ MIS   ┆ … ┆ 4010       ┆ recursos-e ┆ OS00600078 ┆ manutencao │
# │        ┆            ┆            ┆       ┆   ┆            ┆ mbarcacoes ┆ 9371-P-52- ┆ -inspecao- │
# │        ┆            ┆            ┆       ┆   ┆            ┆            ┆ INSP-DUTO- ┆ submarina/ │
# │        ┆            ┆            ┆       ┆   ┆            ┆            ┆ …          ┆ …          │
# │ 112428 ┆ 6000749623 ┆ 4          ┆ MER   ┆ … ┆ 4010       ┆ recursos-e ┆ OS00600074 ┆ manutencao │
# │        ┆            ┆            ┆       ┆   ┆            ┆ mbarcacoes ┆ 9623-P-67- ┆ -inspecao- │
# │        ┆            ┆            ┆       ┆   ┆            ┆            ┆ POS-PULL-I ┆ submarina/ │
# │        ┆            ┆            ┆       ┆   ┆            ┆            ┆ …          ┆ …          │
# │ …      ┆ …          ┆ …          ┆ …     ┆ … ┆ …          ┆ …          ┆ …          ┆ …          │
# │ 4178   ┆ 6000487025 ┆ 23557      ┆ EQS   ┆ … ┆ 4010       ┆ recursos-e ┆ OS00600048 ┆ manutencao │
# │        ┆            ┆            ┆       ┆   ┆            ┆ mbarcacoes ┆ 7025-JGCO2 ┆ -inspecao- │
# │        ┆            ┆            ┆       ┆   ┆            ┆            ┆ 1-014      ┆ submarina/ │
# │        ┆            ┆            ┆       ┆   ┆            ┆            ┆            ┆ …          │
# │ 4177   ┆ 6000486667 ┆ 23558      ┆ EQS   ┆ … ┆ 4010       ┆ recursos-e ┆ OS00600048 ┆ manutencao │
# │        ┆            ┆            ┆       ┆   ┆            ┆ mbarcacoes ┆ 6667-JGCRT ┆ -inspecao- │
# │        ┆            ┆            ┆       ┆   ┆            ┆            ┆ 21-020     ┆ submarina/ │
# │        ┆            ┆            ┆       ┆   ┆            ┆            ┆            ┆ …          │
# │ 4107   ┆ 6000558142 ┆ 23559      ┆ EQS   ┆ … ┆ 4010       ┆ recursos-e ┆ OS00600055 ┆ manutencao │
# │        ┆            ┆            ┆       ┆   ┆            ┆ mbarcacoes ┆ 8142-JGMRL ┆ -inspecao- │
# │        ┆            ┆            ┆       ┆   ┆            ┆            ┆ 21-027     ┆ submarina/ │
# │        ┆            ┆            ┆       ┆   ┆            ┆            ┆            ┆ …          │
# │ 3292   ┆ 6000530044 ┆ 23226      ┆ SFA   ┆ … ┆ 4010       ┆ recursos-e ┆ OS00600053 ┆ manutencao │
# │        ┆            ┆            ┆       ┆   ┆            ┆ mbarcacoes ┆ 0044-SACBU ┆ -inspecao- │
# │        ┆            ┆            ┆       ┆   ┆            ┆            ┆ Z20-139    ┆ submarina/ │
# │        ┆            ┆            ┆       ┆   ┆            ┆            ┆            ┆ …          │
# │ 1904   ┆ 6000553476 ┆ 23560      ┆ MER   ┆ … ┆ 4010       ┆ frente-uni ┆ 2020-10-13 ┆ manutencao │
# │        ┆            ┆            ┆       ┆   ┆            ┆ dade-estac ┆ -OS0060005 ┆ -inspecao- │
# │        ┆            ┆            ┆       ┆   ┆            ┆ ionaria-pr ┆ 53476-PIDF ┆ submarina/ │
# │        ┆            ┆            ┆       ┆   ┆            ┆ …          ┆ …          ┆ …          │
# └────────┴────────────┴────────────┴───────┴───┴────────────┴────────────┴────────────┴────────────┘

# %%
# !conda env list
# Out:
# /bin/bash: line 1: conda: command not found

# %%
pip install xlsx2csv
# Out:
# ERROR: Could not find an activated virtualenv (required).
# Note: you may need to restart the kernel to use updated packages.

# %%
# !rm -rf lib

# %%
# !jupyter kernelspec list
# Out:
# Available kernels:
#   ir         /usr/local/share/jupyter/kernels/ir
#   python3    /usr/local/share/jupyter/kernels/python3

# %%
# !export PATH="$HOME/miniforge3/bin:$PATH"

# %%
# !conda env list
# Out:
# /bin/bash: line 1: conda: command not found
