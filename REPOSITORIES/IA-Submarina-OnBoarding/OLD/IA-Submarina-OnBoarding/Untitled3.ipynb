# %%
import polars as pl
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import polars as pl
#
# ModuleNotFoundError: No module named 'polars'

# %%
import polars as pl
df = pl.read_excel("myfile.xlsx")
print(df)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import polars as pl
#       2 df = pl.read_excel("myfile.xlsx")
#       3 print(df)
#
# ModuleNotFoundError: No module named 'polars'

# %%
# !conda
# Out:
# /bin/bash: line 1: conda: command not found
