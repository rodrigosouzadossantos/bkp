# %% [markdown]
# # RT-DETR - Modelo de Detecção baseado em Transformer
#
# Autor:  Viviane da Rosa Sommer
#
# Atualizado: 16/04/2025
#
# ## Objetivo: Execução de fine tunning do modelo no nosso dataset, para avaliar o modelo.

# %%
from ultralytics import RTDETR

model = RTDETR("rtdetr-l.pt")
results = model.train(data="coral.yaml", epochs=100, imgsz=800)
