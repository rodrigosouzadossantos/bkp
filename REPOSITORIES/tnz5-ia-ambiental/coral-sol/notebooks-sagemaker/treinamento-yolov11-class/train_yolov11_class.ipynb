# %% [markdown]
# # Treinamento - YOLOv11 - Classificação
#
# Autor:  Viviane da Rosa Sommer
#
# Atualizado: 21/02/2024
#
# ## Objetivo:
# Notebook para treinar a YOLOv11 de classificação.

# %% [markdown]
# ## Importações Necessárias

# %%
# !pip install opencv-python-headless
from ultralytics import YOLO

# %% [markdown]
# ## Treinamento do modelo

# %%
model = YOLO("yolo11n-cls.pt")
model.model.nc = 2
results = model.train(data="Datasets/Dataset-Classificacao-Images-V3",
                      epochs=500,
                      imgsz=800)

# %%
# !jupyter nbconvert --to html train_yolov11_class.ipynb
