# %% [markdown]
# # Treinamento de Modelo de Segmentação - YoloV11
#
# Autor:  Viviane da Rosa Sommer
#
# Atualizado: 17/01/2025
#
# ## Objetivo:
# Este notebook foi desenvolvido para realizar o treinamento da YoloV11, especificamente configurada para tarefas de segmentação, utilizando o modelo no tamanho nano. O treinamento tem como objetivo explorar a capacidade do modelo em identificar e segmentar objetos de forma eficiente, mesmo em cenários com limitações de recursos computacionais, mantendo um desempenho satisfatório em termos de precisão e velocidade.

# %% [markdown]
# ## Importações Necessárias

# %%
from ultralytics import YOLO

# %% [markdown]
# ## Treino do Modelo YoloV11

# %%
model = YOLO("yolo11n-seg.pt")
results = model.train( data="coral.yaml", imgsz=800, epochs=500)

# %%
# !jupyter nbconvert --to html PUC-Legado-MSOV1-MSOV2.ipynb
