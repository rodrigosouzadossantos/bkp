# %%
import marimo as mo
# Out:
# [D 260220 23:10:38 cell_runner:742] Running post_execution hooks in context
# [D 260220 23:10:38 hooks_post_execution:65] Acquiring graph lock to update cell import workspace
# [D 260220 23:10:38 hooks_post_execution:67] Acquired graph lock to update import workspace.

# %%
diagram = '''
graph LR
    A[Square Rect] -- Link text --> B((Circle))
    A --> C(Round Rect)
    B --> D{Rhombus}
    C --> D
'''
mo.mermaid(diagram)
# Out:
# [D 260220 23:10:38 cell_runner:742] Running post_execution hooks in context
# [D 260220 23:10:38 hooks_post_execution:65] Acquiring graph lock to update cell import workspace
# [D 260220 23:10:38 hooks_post_execution:67] Acquired graph lock to update import workspace.
# <marimo-mermaid data-diagram='&quot;&#92;ngraph LR&#92;n    A[Square Rect] -- Link text --&gt; B((Circle))&#92;n    A --&gt; C(Round Rect)&#92;n    B --&gt; D{Rhombus}&#92;n    C --&gt; D&#92;n&quot;'></marimo-mermaid>

# %%
import cv2
import PIL
import torch
import torchvision
import ultralytics
import numpy as np

print(f"OpenCV: {cv2.__version__}")
print(f"Pillow: {PIL.__version__}")
print(f"Torch: {torch.__version__}")
print(f"Torchvision: {torchvision.__version__}")
print(f"Ultralytics (YOLO): {ultralytics.__version__}")
print(f"Numpy: {np.__version__}")
# Out:
# OpenCV: 4.13.0
# Pillow: 12.1.1
# Torch: 2.10.0+cu128
# Torchvision: 0.25.0+cu128
# Ultralytics (YOLO): 8.4.14
# Numpy: 2.4.2
# [D 260220 23:09:41 cell_runner:742] Running post_execution hooks in context
# [D 260220 23:09:41 hooks_post_execution:65] Acquiring graph lock to update cell import workspace
# [D 260220 23:09:41 hooks_post_execution:67] Acquired graph lock to update import workspace.
