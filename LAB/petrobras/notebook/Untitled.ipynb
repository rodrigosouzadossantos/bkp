# %%
import petrobras
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import petrobras
#
# File ~/LAB/petrobras/src/petrobras/__init__.py:18
#      16 from .core.observer import Observer
#      17 from .core.observer_logger import ObserverLogger
# ---> 18 from .core.observer_ui import ObserverUI
#      19 from .core.output_router import OutputRouter
#      21 from .lib.config.logging import configure_observer_logging
#
# File ~/LAB/petrobras/src/petrobras/core/observer_ui.py:12
#       9 import atexit
#      10 from collections import deque
# ---> 12 from rich.console import Console, Group
#      13 from rich.panel import Panel
#      14 from rich.live import Live
#
# ModuleNotFoundError: No module named 'rich'
